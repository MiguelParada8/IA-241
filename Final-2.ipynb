# %%
# %matplotlib inline
import pandas

# %% [markdown]
# # Import Data

# %%
df = pandas.read_excel('s3://paradaia241/COVID-19-geographic-disbtribution-worldwide.xlsx')
df[:10] #the top 10 rows
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-04-28   28      4  2020    172       0             Afghanistan    AF
# 1 2020-04-27   27      4  2020     68      10             Afghanistan    AF
# 2 2020-04-26   26      4  2020    112       4             Afghanistan    AF
# 3 2020-04-25   25      4  2020     70       1             Afghanistan    AF
# 4 2020-04-24   24      4  2020    105       2             Afghanistan    AF
# 5 2020-04-23   23      4  2020     84       4             Afghanistan    AF
# 6 2020-04-22   22      4  2020     61       1             Afghanistan    AF
# 7 2020-04-21   21      4  2020     35       2             Afghanistan    AF
# 8 2020-04-20   20      4  2020     88       3             Afghanistan    AF
# 9 2020-04-19   19      4  2020     63       0             Afghanistan    AF
#
#   countryterritoryCode  popData2018 continentExp
# 0                  AFG   37172386.0         Asia
# ...

# %% [markdown]
# # COVID-19 Explanation:
# COVID-19 is a a respiratory disease that is spreading gloabally, infecting millsions of people. Nation's governments are issuing isolation procedures to stop the spread of virus. National research labs are working quickly to construct a vaccine, which might take up to two years.

# %% [markdown]
# # 1. Top 20 Countries with Highest Number of Cases

# %%
sum_cases_by_country = df.groupby('countriesAndTerritories').sum()['cases']
sum_cases_by_country.nlargest(20).plot.bar()

# %% [markdown]
# # Interpretation:
# This graph shows the Top 20 Countries with the most positive cases of COVID-19.

# %% [markdown]
# # 2. Select Spain Data

# %%
Spain_data = df.loc[df['countriesAndTerritories'] == 'Spain']
Spain_data[:15] #the top 15 rows
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 11668 2020-04-27   27      4  2020   1831       0                   Spain
# 11669 2020-04-26   26      4  2020   1729     288                   Spain
# 11670 2020-04-25   25      4  2020   2944     378                   Spain
# 11671 2020-04-24   24      4  2020   2767     367                   Spain
# 11672 2020-04-23   23      4  2020   3052     440                   Spain
# 11673 2020-04-22   22      4  2020   2627     435                   Spain
# 11674 2020-04-21   21      4  2020   3352     430                   Spain
# 11675 2020-04-20   20      4  2020   2585     399                   Spain
# 11676 2020-04-19   19      4  2020  -1430     410                   Spain
# 11677 2020-04-18   18      4  2020   4104     565                   Spain
# 11678 2020-04-17   17      4  2020   4400     585                   Spain
# 11679 2020-04-16   16      4  2020   4040     617                   Spain
# ...

# %% [markdown]
# # Spain's Death Rate Increase Per Month

# %%
Spain_data = df.loc[df['countriesAndTerritories'] == 'Spain'].groupby('dateRep').sum()['deaths']
Spain_data.plot()

# %% [markdown]
# # Interpretation:
# The line graph exhibits the death rate in Spain, showing that April produced the most spikes.

# %% [markdown]
# # 3. Select Turkey Data

# %%
Turkey_data = df.loc[df['countriesAndTerritories'] == 'Turkey']
Turkey_data[:15] #the top 15 rows
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 12674 2020-04-28   28      4  2020   2131      95                  Turkey
# 12675 2020-04-27   27      4  2020   2357      99                  Turkey
# 12676 2020-04-26   26      4  2020   2861     106                  Turkey
# 12677 2020-04-25   25      4  2020   3122     109                  Turkey
# 12678 2020-04-24   24      4  2020   3116     115                  Turkey
# 12679 2020-04-23   23      4  2020   3083     117                  Turkey
# 12680 2020-04-22   22      4  2020   4611     119                  Turkey
# 12681 2020-04-21   21      4  2020   4674     123                  Turkey
# 12682 2020-04-20   20      4  2020   3977     127                  Turkey
# 12683 2020-04-19   19      4  2020   3783     121                  Turkey
# 12684 2020-04-18   18      4  2020   4353     126                  Turkey
# 12685 2020-04-17   17      4  2020   4801     125                  Turkey
# ...

# %% [markdown]
# # Turkey's Infection Rate Increase Per Month

# %%
Turkey_data = df.loc[df['countriesAndTerritories'] == 'Turkey'].groupby('dateRep').mean()['cases']
Turkey_data.plot()

# %% [markdown]
# # Interpretation:
# The line graph exhibits the increase rate in the number of positive COVID-19 cases in Turkey, showing that March produced a steady incline.

# %% [markdown]
# # 4. Number of Deaths Per Continent

# %%
global_data = df.groupby('continentExp').sum()['deaths']
global_data.plot.bar()

# %% [markdown]
# # Interpretation:
# The bar graph shows the number COVID-19 related deaths within each continent(continents chosen using the contintentExp Column). Europe is the continent with the most confirmed deaths, as America is the second highest.

# %% [markdown]
# # 5. Number of Cases Per Continent

# %%
global_data = df.groupby('continentExp').sum()['cases']
global_data.plot.bar()

# %% [markdown]
# # Interpretation:
# The bar graph shows the number of positive COVID-19 cases within each continent(continents chosen using the contintentExp Column). Europe is the continent with the most positive cases, as America is a close second.

# %% [markdown]
# # Data Source: ECDC Europa
# Link: https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide

# %% [markdown]
# # Limitations:
# 1. One Source Used
# 2. Pandemic is still ongoing
# 3. Restricted Python Coding Skills

# %% [markdown]
# # Suggestions For Improvement:
# 1. Use more sources that are constantly updating
# 2. Gain more higher level Pthyon coding

# %% [markdown]
# # Conclusion:
# Based on the data collected, COVID-19 infection peak between Turkey and Spain was between March and April. Europe and America have the most confirmed cases, with Europe leading with highest number of deaths. As individual nations, the United States of America average the highest number of cases.
